# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-00/edd_1310_2021/blob/master/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arch = open("Datos.txt", 'rt')
dato = arch.read().replace(" ", "")
res = dato.split("\n")
ele = res[0].split(",")
print("Los elementos de la primera fila son:")
print(res[0])
print("La suma de la fila es:")

res1 = [int (x) for x in ele]
a = sum(res1)
print(a)

dato = arch.read().replace(" ", "")
ele = res[2].split(",")
print("Los elementos de la segunda fila son:")
print(res[2])
print("La suma de la fila es:")

res2 = [int (x) for x in ele]
b = sum(res2)
print(b)

dato = arch.read().replace(" ", "")
ele = res[4].split(",")
print("Los elementos de la tercera fila son:")
print(res[4])
print("La suma de la fila es:")

res3 = [int (x) for x in ele]
c = sum(res3)
print(c)

dato = arch.read().replace(" ", "")
ele = res[6].split(",")
print("Los elementos de la cuarta fila son:")
print(res[6])
print("La suma de la fila es:")

res4 = [int (x) for x in ele]
d = sum(res4)
print(d)

dato = arch.read().replace(" ", "")
ele = res[8].split(",")
print("Los elementos de la quinta fila son:")
print(res[8])
print("La suma de la fila es:")

res5 = [int (x) for x in ele]
e = sum(res5)
print(e)

dato = arch.read().replace(" ", "")
ele = res[10].split(",")
print("Los elementos de la sexta fila son:")
print(res[10])
print("La suma de la fila es:")

res6 = [int (x) for x in ele]
f = sum(res6)
print(f)

dato = arch.read().replace(" ", "")
ele = res[12].split(",")
print("Los elementos de la septima fila son:")
print(res[12])
print("La suma de la fila es:")

res7 = [int (x) for x in ele]
g = sum(res7)
print(g)

dato = arch.read().replace(" ", "")
ele = res[14].split(",")
print("Los elementos de la octava fila son:")
print(res[14])
print("La suma de la fila es:")

res8 = [int (x) for x in ele]
h = sum(res8)
print(h)

dato = arch.read().replace(" ", "")
ele = res[16].split(",")
print("Los elementos de la novena fila son:")
print(res[16])
print("La suma de la fila es:")

res9 = [int (x) for x in ele]
i = sum(res9)
print(i)

dato = arch.read().replace(" ", "")
ele = res[18].split(",")
print("Los elementos de la decima fila son:")
print(res[18])
print("La suma de la fila es:")

res10 = [int (x) for x in ele]
j= sum(res10)
print(j)


def sumar(a,b,c,d,e,f,g,h,i,j):
  resultado = a+b+c+d+e+f+g+h+i+j 
  return resultado

print("La suma total de las filas es:")
sumar(a,b,c,d,e,f,g,h,i,j)
# Out:
# Los elementos de la primera fila son:
# 1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10
# La suma de la fila es:
# 406
# Los elementos de la segunda fila son:
# 2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2
# La suma de la fila es:
# 367
# Los elementos de la tercera fila son:
# 3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93
# La suma de la fila es:
# 814
# Los elementos de la cuarta fila son:
# 4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45
# La suma de la fila es:
# 418
# Los elementos de la quinta fila son:
# 55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62
# La suma de la fila es:
# 786
# Los elementos de la sexta fila son:
# 6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52
# La suma de la fila es:
# 513
# Los elementos de la septima fila son:
# 7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7
# La suma de la fila es:
# 745
# Los elementos de la octava fila son:
# 8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2
# ...
